# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("HuGaDB.db")
df = pd.read_sql_query("SELECT * FROM data", conn)
files_df = pd.read_sql_query("SELECT * FROM files", conn)
conn.close()

print(df.head())
print(df.shape)

# %%
df.columns

# %%
print(df['act'].unique())

# %%
walking_df = df[df['act'] == 1]

# %%
walking_df.head()
